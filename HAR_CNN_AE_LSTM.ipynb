# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Jan 20 03:35:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    29W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/HAR
# Out:
# /content/drive/My Drive/HAR

# %%
# %ls
# Out:
# HAR_CNN_AE_LSTM.ipynb        t-sne_perp_20_iter_1000.png
# HAR_EDA.ipynb                t-sne_perp_2_iter_1000.png
# HAR_PREDICTION_MODELS.ipynb  t-sne_perp_50_iter_1000.png
# model_plot.png               t-sne_perp_5_iter_1000.png
# t-sne_perp_10_iter_1000.png  UCI_HAR_Dataset/

# %%
import pandas as pd
import numpy as np

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %% [markdown]
# ### Data

# %%
# Data directory
DATADIR = 'UCI_HAR_Dataset'

# %%
# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'UCI_HAR_Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).to_numpy()
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = f'UCI_HAR_Dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).to_numpy()

# %%
def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %%
# Importing tensorflow
np.random.seed(42)
import tensorflow as tf
tf.random.set_seed(42)

# %%
# Configuring a session
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)

# %%
# Import Keras
from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout

# %%
# Initializing parameters
epochs = 200
batch_size = 128

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
print(X_train.shape)
# Out:
# 128
# 9
# 7352
# (7352, 128, 9)

# %%
# reshape data into time steps of sub-sequences
n_steps, n_length = 4, 32
n_features = input_dim
X_train = X_train.reshape((X_train.shape[0], n_steps, n_length, n_features))
X_test = X_test.reshape((X_test.shape[0], n_steps, n_length, n_features))

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters

#Convolutional AE


model.add(
    tf.keras.layers.TimeDistributed(
        tf.keras.layers.Conv1D(
            filters=64, kernel_size=3,strides=2,
            activation="relu",
            input_shape=(n_length, n_features)
        )
    )
)

model.add(
    tf.keras.layers.TimeDistributed(
      tf.keras.layers.MaxPool1D(pool_size=2, strides=2)
    )
)



model.add(
    tf.keras.layers.TimeDistributed(
        tf.keras.layers.Conv1DTranspose(
            filters=64, kernel_size=3,strides=2,
            activation="relu"
        )
    )
)


model.add(
    tf.keras.layers.TimeDistributed(
        tf.keras.layers.Flatten()
    ) 
)

model.add(Dropout(0.5))

model.add(LSTM(64))


# Adding a dense layer with relu activation
model.add(Dense(64, activation='relu'))

# Adding a dense layer with relu activation
model.add(Dense(64, activation='relu'))

model.add(Dense(n_classes, activation='softmax'))

# model.summary()

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in summary(self, line_length, positions, print_fn, expand_nested, show_trainable)
#    2867     """
#    2868     if not self.built:
# -> 2869       raise ValueError(
#    2870           'This model has not yet been built. '
#    2871           'Build the model first by calling `build()` or by calling '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Training the model

history = model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=200)


import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 58/58 [==============================] - 13s 17ms/step - loss: 0.8111 - accuracy: 0.6836 - val_loss: 0.6221 - val_accuracy: 0.7363
# Epoch 2/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.3410 - accuracy: 0.8649 - val_loss: 0.5221 - val_accuracy: 0.8164
# Epoch 3/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.2190 - accuracy: 0.9140 - val_loss: 0.4262 - val_accuracy: 0.8480
# Epoch 4/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1635 - accuracy: 0.9344 - val_loss: 0.5173 - val_accuracy: 0.8334
# Epoch 5/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1397 - accuracy: 0.9429 - val_loss: 0.4129 - val_accuracy: 0.8843
# Epoch 6/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.1232 - accuracy: 0.9478 - val_loss: 0.4063 - val_accuracy: 0.8826
# Epoch 7/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.1154 - accuracy: 0.9525 - val_loss: 0.4669 - val_accuracy: 0.8839
# Epoch 8/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1139 - accuracy: 0.9523 - val_loss: 0.4480 - val_accuracy: 0.8772
# Epoch 9/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.1170 - accuracy: 0.9521 - val_loss: 0.4277 - val_accuracy: 0.8741
# Epoch 10/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1084 - accuracy: 0.9562 - val_loss: 0.3267 - val_accuracy: 0.8935
# Epoch 11/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1016 - accuracy: 0.9557 - val_loss: 0.3317 - val_accuracy: 0.9006
# Epoch 12/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1033 - accuracy: 0.9544 - val_loss: 0.4071 - val_accuracy: 0.8782
# Epoch 13/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1046 - accuracy: 0.9527 - val_loss: 0.4043 - val_accuracy: 0.8914
# Epoch 14/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0984 - accuracy: 0.9574 - val_loss: 0.3695 - val_accuracy: 0.8873
# Epoch 15/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0942 - accuracy: 0.9591 - val_loss: 0.4020 - val_accuracy: 0.8931
# Epoch 16/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0950 - accuracy: 0.9591 - val_loss: 0.3877 - val_accuracy: 0.8795
# Epoch 17/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0974 - accuracy: 0.9555 - val_loss: 0.4476 - val_accuracy: 0.8918
# Epoch 18/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.1011 - accuracy: 0.9547 - val_loss: 0.4378 - val_accuracy: 0.8839
# Epoch 19/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0949 - accuracy: 0.9577 - val_loss: 0.4823 - val_accuracy: 0.8907
# Epoch 20/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0914 - accuracy: 0.9595 - val_loss: 0.4620 - val_accuracy: 0.8935
# Epoch 21/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0864 - accuracy: 0.9619 - val_loss: 0.5523 - val_accuracy: 0.8846
# Epoch 22/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0863 - accuracy: 0.9601 - val_loss: 0.4277 - val_accuracy: 0.8958
# Epoch 23/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0827 - accuracy: 0.9606 - val_loss: 0.4333 - val_accuracy: 0.9043
# Epoch 24/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0920 - accuracy: 0.9573 - val_loss: 0.6609 - val_accuracy: 0.8517
# Epoch 25/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1044 - accuracy: 0.9504 - val_loss: 0.3715 - val_accuracy: 0.9043
# Epoch 26/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0781 - accuracy: 0.9645 - val_loss: 0.4409 - val_accuracy: 0.9030
# Epoch 27/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0755 - accuracy: 0.9644 - val_loss: 0.4405 - val_accuracy: 0.8989
# Epoch 28/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9604 - val_loss: 0.4163 - val_accuracy: 0.9026
# Epoch 29/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0697 - accuracy: 0.9650 - val_loss: 0.4434 - val_accuracy: 0.8901
# Epoch 30/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0781 - accuracy: 0.9626 - val_loss: 0.4068 - val_accuracy: 0.9080
# Epoch 31/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0759 - accuracy: 0.9633 - val_loss: 0.3459 - val_accuracy: 0.8833
# Epoch 32/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0697 - accuracy: 0.9667 - val_loss: 0.4105 - val_accuracy: 0.8921
# Epoch 33/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0689 - accuracy: 0.9671 - val_loss: 0.4594 - val_accuracy: 0.8985
# Epoch 34/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0926 - accuracy: 0.9584 - val_loss: 0.5070 - val_accuracy: 0.8738
# Epoch 35/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0700 - accuracy: 0.9664 - val_loss: 0.4382 - val_accuracy: 0.8884
# Epoch 36/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0640 - accuracy: 0.9713 - val_loss: 0.4532 - val_accuracy: 0.8972
# Epoch 37/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0596 - accuracy: 0.9712 - val_loss: 0.4269 - val_accuracy: 0.8877
# Epoch 38/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0608 - accuracy: 0.9701 - val_loss: 0.4703 - val_accuracy: 0.8924
# Epoch 39/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0591 - accuracy: 0.9708 - val_loss: 0.4664 - val_accuracy: 0.8792
# Epoch 40/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 0.9693 - val_loss: 0.4762 - val_accuracy: 0.8921
# Epoch 41/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0565 - accuracy: 0.9735 - val_loss: 0.4711 - val_accuracy: 0.8846
# Epoch 42/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0599 - accuracy: 0.9720 - val_loss: 0.4528 - val_accuracy: 0.8799
# Epoch 43/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0605 - accuracy: 0.9699 - val_loss: 0.5406 - val_accuracy: 0.8931
# Epoch 44/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0561 - accuracy: 0.9706 - val_loss: 0.4789 - val_accuracy: 0.8846
# Epoch 45/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0524 - accuracy: 0.9737 - val_loss: 0.4697 - val_accuracy: 0.8921
# Epoch 46/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0595 - accuracy: 0.9693 - val_loss: 0.5322 - val_accuracy: 0.8721
# Epoch 47/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0520 - accuracy: 0.9740 - val_loss: 0.4908 - val_accuracy: 0.8907
# Epoch 48/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0556 - accuracy: 0.9703 - val_loss: 0.5064 - val_accuracy: 0.8839
# Epoch 49/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0573 - accuracy: 0.9729 - val_loss: 0.5273 - val_accuracy: 0.8884
# Epoch 50/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0510 - accuracy: 0.9733 - val_loss: 0.5387 - val_accuracy: 0.8914
# Epoch 51/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0497 - accuracy: 0.9743 - val_loss: 0.4816 - val_accuracy: 0.8941
# Epoch 52/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0513 - accuracy: 0.9759 - val_loss: 0.5166 - val_accuracy: 0.8945
# Epoch 53/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0657 - accuracy: 0.9679 - val_loss: 0.5114 - val_accuracy: 0.8853
# Epoch 54/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0478 - accuracy: 0.9747 - val_loss: 0.5314 - val_accuracy: 0.8768
# Epoch 55/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0524 - accuracy: 0.9744 - val_loss: 0.5464 - val_accuracy: 0.8846
# Epoch 56/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0603 - accuracy: 0.9752 - val_loss: 0.4272 - val_accuracy: 0.8928
# Epoch 57/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0608 - accuracy: 0.9716 - val_loss: 0.4188 - val_accuracy: 0.8931
# Epoch 58/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0460 - accuracy: 0.9742 - val_loss: 0.4806 - val_accuracy: 0.8907
# Epoch 59/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0437 - accuracy: 0.9752 - val_loss: 0.5051 - val_accuracy: 0.8935
# Epoch 60/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0415 - accuracy: 0.9771 - val_loss: 0.4947 - val_accuracy: 0.8812
# Epoch 61/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0472 - accuracy: 0.9777 - val_loss: 0.5010 - val_accuracy: 0.8846
# Epoch 62/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0405 - accuracy: 0.9788 - val_loss: 0.5333 - val_accuracy: 0.8904
# Epoch 63/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0450 - accuracy: 0.9786 - val_loss: 0.5147 - val_accuracy: 0.8880
# Epoch 64/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0454 - accuracy: 0.9776 - val_loss: 0.4694 - val_accuracy: 0.8982
# Epoch 65/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0413 - accuracy: 0.9786 - val_loss: 0.6336 - val_accuracy: 0.8809
# Epoch 66/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0598 - accuracy: 0.9727 - val_loss: 0.5328 - val_accuracy: 0.8901
# Epoch 67/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0394 - accuracy: 0.9812 - val_loss: 0.5396 - val_accuracy: 0.8823
# Epoch 68/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0387 - accuracy: 0.9793 - val_loss: 0.5726 - val_accuracy: 0.8839
# Epoch 69/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0361 - accuracy: 0.9808 - val_loss: 0.5841 - val_accuracy: 0.8839
# Epoch 70/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0349 - accuracy: 0.9820 - val_loss: 0.6018 - val_accuracy: 0.8802
# Epoch 71/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0328 - accuracy: 0.9842 - val_loss: 0.6084 - val_accuracy: 0.8887
# Epoch 72/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0307 - accuracy: 0.9844 - val_loss: 0.6033 - val_accuracy: 0.8856
# Epoch 73/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0391 - accuracy: 0.9816 - val_loss: 0.5849 - val_accuracy: 0.8951
# Epoch 74/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0393 - accuracy: 0.9807 - val_loss: 0.6230 - val_accuracy: 0.8935
# Epoch 75/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0373 - accuracy: 0.9819 - val_loss: 0.6079 - val_accuracy: 0.8938
# Epoch 76/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0307 - accuracy: 0.9835 - val_loss: 0.5791 - val_accuracy: 0.8935
# Epoch 77/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 0.9830 - val_loss: 0.6469 - val_accuracy: 0.8829
# Epoch 78/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0321 - accuracy: 0.9857 - val_loss: 0.5877 - val_accuracy: 0.8941
# Epoch 79/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0310 - accuracy: 0.9841 - val_loss: 0.5933 - val_accuracy: 0.8819
# Epoch 80/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0304 - accuracy: 0.9842 - val_loss: 0.5669 - val_accuracy: 0.8972
# Epoch 81/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0245 - accuracy: 0.9878 - val_loss: 0.5941 - val_accuracy: 0.8945
# Epoch 82/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0242 - accuracy: 0.9879 - val_loss: 0.6224 - val_accuracy: 0.8914
# Epoch 83/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9859 - val_loss: 0.6299 - val_accuracy: 0.8839
# Epoch 84/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0351 - accuracy: 0.9826 - val_loss: 0.7947 - val_accuracy: 0.8792
# Epoch 85/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0445 - accuracy: 0.9808 - val_loss: 0.5135 - val_accuracy: 0.8880
# Epoch 86/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0247 - accuracy: 0.9878 - val_loss: 0.6110 - val_accuracy: 0.8962
# Epoch 87/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0252 - accuracy: 0.9874 - val_loss: 0.5585 - val_accuracy: 0.8985
# Epoch 88/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 0.9887 - val_loss: 0.5916 - val_accuracy: 0.9016
# Epoch 89/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0239 - accuracy: 0.9880 - val_loss: 0.5661 - val_accuracy: 0.8965
# Epoch 90/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0315 - accuracy: 0.9853 - val_loss: 0.5648 - val_accuracy: 0.9046
# Epoch 91/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 0.9827 - val_loss: 0.4670 - val_accuracy: 0.9135
# Epoch 92/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9872 - val_loss: 0.4661 - val_accuracy: 0.9097
# Epoch 93/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9883 - val_loss: 0.5108 - val_accuracy: 0.9101
# Epoch 94/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0245 - accuracy: 0.9878 - val_loss: 0.5283 - val_accuracy: 0.9080
# Epoch 95/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0236 - accuracy: 0.9894 - val_loss: 0.4985 - val_accuracy: 0.9121
# Epoch 96/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.9901 - val_loss: 0.5458 - val_accuracy: 0.9070
# Epoch 97/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0215 - accuracy: 0.9901 - val_loss: 0.4871 - val_accuracy: 0.9091
# Epoch 98/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0341 - accuracy: 0.9864 - val_loss: 0.5055 - val_accuracy: 0.9104
# Epoch 99/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0283 - accuracy: 0.9857 - val_loss: 0.5147 - val_accuracy: 0.9019
# Epoch 100/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.5727 - val_accuracy: 0.9070
# Epoch 101/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0262 - accuracy: 0.9886 - val_loss: 0.5247 - val_accuracy: 0.9040
# Epoch 102/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 0.9906 - val_loss: 0.6080 - val_accuracy: 0.9030
# Epoch 103/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0265 - accuracy: 0.9872 - val_loss: 0.5126 - val_accuracy: 0.9087
# Epoch 104/200
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0189 - accuracy: 0.9903 - val_loss: 0.6138 - val_accuracy: 0.9026
# Epoch 105/200
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0203 - accuracy: 0.9916 - val_loss: 0.5828 - val_accuracy: 0.9070
# Epoch 106/200
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0350 - accuracy: 0.9864 - val_loss: 0.5339 - val_accuracy: 0.9053
# Epoch 107/200
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0162 - accuracy: 0.9931 - val_loss: 0.4911 - val_accuracy: 0.9077
# Epoch 108/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0174 - accuracy: 0.9929 - val_loss: 0.5476 - val_accuracy: 0.9158
# Epoch 109/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0159 - accuracy: 0.9927 - val_loss: 0.6084 - val_accuracy: 0.9057
# Epoch 110/200
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0159 - accuracy: 0.9932 - val_loss: 0.5869 - val_accuracy: 0.9043
# Epoch 111/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0132 - accuracy: 0.9940 - val_loss: 0.5734 - val_accuracy: 0.9043
# Epoch 112/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0172 - accuracy: 0.9933 - val_loss: 0.6038 - val_accuracy: 0.9033
# Epoch 113/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 0.9937 - val_loss: 0.5776 - val_accuracy: 0.9138
# Epoch 114/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.9933 - val_loss: 0.5428 - val_accuracy: 0.9230
# Epoch 115/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0403 - accuracy: 0.9845 - val_loss: 0.4500 - val_accuracy: 0.9070
# Epoch 116/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 0.9946 - val_loss: 0.6038 - val_accuracy: 0.8982
# Epoch 117/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0185 - accuracy: 0.9914 - val_loss: 0.5993 - val_accuracy: 0.9067
# Epoch 118/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 0.9916 - val_loss: 0.5637 - val_accuracy: 0.9067
# Epoch 119/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0243 - accuracy: 0.9901 - val_loss: 0.5634 - val_accuracy: 0.9104
# Epoch 120/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.9931 - val_loss: 0.5498 - val_accuracy: 0.9169
# Epoch 121/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 0.5866 - val_accuracy: 0.9121
# Epoch 122/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0084 - accuracy: 0.9959 - val_loss: 0.6171 - val_accuracy: 0.9125
# Epoch 123/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9951 - val_loss: 0.7155 - val_accuracy: 0.9006
# Epoch 124/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 0.9927 - val_loss: 0.6307 - val_accuracy: 0.9060
# Epoch 125/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0247 - accuracy: 0.9890 - val_loss: 0.5742 - val_accuracy: 0.9077
# Epoch 126/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 0.9935 - val_loss: 0.6769 - val_accuracy: 0.9050
# Epoch 127/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9933 - val_loss: 0.7119 - val_accuracy: 0.9087
# Epoch 128/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.6240 - val_accuracy: 0.9152
# Epoch 129/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 0.5685 - val_accuracy: 0.9189
# Epoch 130/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9959 - val_loss: 0.6090 - val_accuracy: 0.9101
# Epoch 131/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9961 - val_loss: 0.6715 - val_accuracy: 0.9155
# Epoch 132/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9955 - val_loss: 0.5952 - val_accuracy: 0.9148
# Epoch 133/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 0.9954 - val_loss: 0.6910 - val_accuracy: 0.8999
# Epoch 134/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.9951 - val_loss: 0.6060 - val_accuracy: 0.9033
# Epoch 135/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0197 - accuracy: 0.9927 - val_loss: 0.5687 - val_accuracy: 0.9114
# Epoch 136/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 0.9959 - val_loss: 0.5825 - val_accuracy: 0.9125
# Epoch 137/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.6611 - val_accuracy: 0.9148
# Epoch 138/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.6476 - val_accuracy: 0.9114
# Epoch 139/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.5991 - val_accuracy: 0.9131
# Epoch 140/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 0.6382 - val_accuracy: 0.9121
# Epoch 141/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 0.9961 - val_loss: 0.6423 - val_accuracy: 0.9111
# Epoch 142/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.6608 - val_accuracy: 0.9111
# Epoch 143/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.6704 - val_accuracy: 0.9108
# Epoch 144/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.5869 - val_accuracy: 0.9125
# Epoch 145/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0153 - accuracy: 0.9939 - val_loss: 0.5829 - val_accuracy: 0.9101
# Epoch 146/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.6785 - val_accuracy: 0.9057
# Epoch 147/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9962 - val_loss: 0.6121 - val_accuracy: 0.9070
# Epoch 148/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.7266 - val_accuracy: 0.9043
# Epoch 149/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9944 - val_loss: 0.7609 - val_accuracy: 0.9023
# Epoch 150/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.5737 - val_accuracy: 0.9175
# Epoch 151/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.6715 - val_accuracy: 0.9063
# Epoch 152/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.7725 - val_accuracy: 0.9013
# Epoch 153/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0134 - accuracy: 0.9943 - val_loss: 0.7007 - val_accuracy: 0.9074
# Epoch 154/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 0.9943 - val_loss: 0.6588 - val_accuracy: 0.9128
# Epoch 155/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.6624 - val_accuracy: 0.9131
# Epoch 156/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.5873 - val_accuracy: 0.9165
# Epoch 157/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 0.9946 - val_loss: 0.6337 - val_accuracy: 0.9169
# Epoch 158/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.7360 - val_accuracy: 0.9155
# Epoch 159/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.5801 - val_accuracy: 0.9179
# Epoch 160/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 0.9935 - val_loss: 0.5820 - val_accuracy: 0.9101
# Epoch 161/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0147 - accuracy: 0.9937 - val_loss: 0.6557 - val_accuracy: 0.9077
# Epoch 162/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 0.9948 - val_loss: 0.6377 - val_accuracy: 0.9101
# Epoch 163/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.7358 - val_accuracy: 0.9097
# Epoch 164/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.6545 - val_accuracy: 0.9162
# Epoch 165/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.7391 - val_accuracy: 0.9108
# Epoch 166/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.7136 - val_accuracy: 0.9189
# Epoch 167/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.7196 - val_accuracy: 0.9182
# Epoch 168/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.7186 - val_accuracy: 0.9172
# Epoch 169/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.7212 - val_accuracy: 0.9148
# Epoch 170/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.7119 - val_accuracy: 0.9223
# Epoch 171/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.7298 - val_accuracy: 0.9165
# Epoch 172/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.6532 - val_accuracy: 0.9097
# Epoch 173/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 0.6632 - val_accuracy: 0.8982
# Epoch 174/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0186 - accuracy: 0.9928 - val_loss: 0.7517 - val_accuracy: 0.8975
# Epoch 175/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.5553 - val_accuracy: 0.9206
# Epoch 176/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.5752 - val_accuracy: 0.9226
# Epoch 177/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.5195 - val_accuracy: 0.9179
# Epoch 178/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.5693 - val_accuracy: 0.9253
# Epoch 179/200
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0066 - accuracy: 0.9969 - val_loss: 0.5924 - val_accuracy: 0.9213
# Epoch 180/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.6548 - val_accuracy: 0.9101
# Epoch 181/200
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.6148 - val_accuracy: 0.9189
# Epoch 182/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.6505 - val_accuracy: 0.9165
# Epoch 183/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.6619 - val_accuracy: 0.9189
# Epoch 184/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.6411 - val_accuracy: 0.9172
# Epoch 185/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.6921 - val_accuracy: 0.9077
# Epoch 186/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0116 - accuracy: 0.9970 - val_loss: 0.6518 - val_accuracy: 0.9162
# Epoch 187/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.6349 - val_accuracy: 0.9192
# Epoch 188/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.6516 - val_accuracy: 0.9209
# Epoch 189/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.6537 - val_accuracy: 0.9158
# Epoch 190/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.5873 - val_accuracy: 0.9172
# Epoch 191/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.6156 - val_accuracy: 0.9145
# Epoch 192/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.5974 - val_accuracy: 0.9169
# Epoch 193/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.6292 - val_accuracy: 0.9220
# Epoch 194/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.7446 - val_accuracy: 0.9118
# Epoch 195/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 0.8634 - val_accuracy: 0.9070
# Epoch 196/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.6514 - val_accuracy: 0.9199
# Epoch 197/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.6047 - val_accuracy: 0.9213
# Epoch 198/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.6623 - val_accuracy: 0.9179
# Epoch 199/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.6938 - val_accuracy: 0.9141
# Epoch 200/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.5685 - val_accuracy: 0.9230
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Confusion Matrix

print(confusion_matrix(Y_test, model.predict(X_test)))
cf_matrix = confusion_matrix(Y_test, model.predict(X_test))

import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(cf_matrix, annot=True, cmap='rocket',fmt='g')
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['LAYING','SITTING','STANDING', 'WALKING' ,'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS'])
ax.yaxis.set_ticklabels(['LAYING','SITTING','STANDING', 'WALKING' ,'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS'])

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# 93/93 [==============================] - 1s 5ms/step
# Pred                LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# True
# LAYING                 510        0         0        0                   0
# SITTING                  0      397        85        0                   0
# STANDING                 0       48       472        4                   0
# WALKING                  0        0         0      485                  11
# WALKING_DOWNSTAIRS       0        0         0        7                 410
# WALKING_UPSTAIRS         0        0         0        6                  19
#
# Pred                WALKING_UPSTAIRS
# True
# LAYING                            27
# SITTING                            9
# STANDING                           8
# WALKING                            0
# WALKING_DOWNSTAIRS                 3
# WALKING_UPSTAIRS                 446
# 93/93 [==============================] - 0s 4ms/step

# %%
score = model.evaluate(X_test, Y_test)
# Out:
# 93/93 [==============================] - 0s 3ms/step - loss: 0.5685 - accuracy: 0.9230

# %%
score
# Out:
# [0.5685434341430664, 0.9229725003242493]

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from datetime import datetime
import sklearn.metrics as metrics
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    # Training the model
    model.fit(X_train,
          y_train,
          batch_size=batch_size,
          validation_data=(X_test, y_test),
          epochs=epochs)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=np.argmax(y_test,axis=1), y_pred=np.argmax(y_pred,axis=1))
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))

    # confusion matrix
    cm = metrics.confusion_matrix(np.argmax(y_test,axis=1), np.argmax(y_pred,axis=1))
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(np.argmax(y_test,axis=1), np.argmax(y_pred,axis=1))
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %%
class_labels = ['LAYING','SITTING','STANDING', 'WALKING' ,'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS']
model_results = perform_model(model, X_train, Y_train, X_test, Y_test, class_labels)
# Out:
# Epoch 1/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.5831 - val_accuracy: 0.9260
# Epoch 2/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.7068 - val_accuracy: 0.9074
# Epoch 3/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.5445 - val_accuracy: 0.9247
# Epoch 4/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.5610 - val_accuracy: 0.9226
# Epoch 5/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.6145 - val_accuracy: 0.9196
# Epoch 6/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.5667 - val_accuracy: 0.9247
# Epoch 7/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.5390 - val_accuracy: 0.9220
# Epoch 8/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.5166 - val_accuracy: 0.9182
# Epoch 9/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.5647 - val_accuracy: 0.9172
# Epoch 10/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.5883 - val_accuracy: 0.9196
# Epoch 11/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.5376 - val_accuracy: 0.9213
# Epoch 12/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.5888 - val_accuracy: 0.9162
# Epoch 13/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.6352 - val_accuracy: 0.9196
# Epoch 14/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.6442 - val_accuracy: 0.9199
# Epoch 15/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.5899 - val_accuracy: 0.9281
# Epoch 16/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.6949 - val_accuracy: 0.9179
# Epoch 17/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.6634 - val_accuracy: 0.9216
# Epoch 18/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.4587 - val_accuracy: 0.9281
# Epoch 19/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.5303 - val_accuracy: 0.9264
# Epoch 20/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.5551 - val_accuracy: 0.9216
# Epoch 21/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.5329 - val_accuracy: 0.9260
# Epoch 22/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.5257 - val_accuracy: 0.9291
# Epoch 23/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.5490 - val_accuracy: 0.9243
# Epoch 24/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.6056 - val_accuracy: 0.9213
# Epoch 25/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.6448e-04 - accuracy: 1.0000 - val_loss: 0.6174 - val_accuracy: 0.9240
# Epoch 26/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.6389 - val_accuracy: 0.9220
# Epoch 27/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.5157 - val_accuracy: 0.9209
# Epoch 28/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.6348 - val_accuracy: 0.9094
# Epoch 29/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.5552 - val_accuracy: 0.9189
# Epoch 30/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.5501 - val_accuracy: 0.9179
# Epoch 31/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.5905 - val_accuracy: 0.9199
# Epoch 32/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.5840 - val_accuracy: 0.9175
# Epoch 33/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.5417 - val_accuracy: 0.9253
# Epoch 34/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.5522 - val_accuracy: 0.9260
# Epoch 35/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 0.5409 - val_accuracy: 0.9247
# Epoch 36/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.5288 - val_accuracy: 0.9291
# Epoch 37/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.5628 - val_accuracy: 0.9220
# Epoch 38/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.5553 - val_accuracy: 0.9274
# Epoch 39/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.5315 - val_accuracy: 0.9294
# Epoch 40/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.5864 - val_accuracy: 0.9274
# Epoch 41/200
# 58/58 [==============================] - 0s 7ms/step - loss: 7.1781e-04 - accuracy: 1.0000 - val_loss: 0.7609 - val_accuracy: 0.9162
# Epoch 42/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.7880e-04 - accuracy: 0.9999 - val_loss: 0.7628 - val_accuracy: 0.9189
# Epoch 43/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.7320 - val_accuracy: 0.9196
# Epoch 44/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.7050 - val_accuracy: 0.9158
# Epoch 45/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.6299 - val_accuracy: 0.9257
# Epoch 46/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.6001 - val_accuracy: 0.9260
# Epoch 47/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.6395 - val_accuracy: 0.9257
# Epoch 48/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.6515 - val_accuracy: 0.9233
# Epoch 49/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.5966 - val_accuracy: 0.9209
# Epoch 50/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.5974 - val_accuracy: 0.9253
# Epoch 51/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.9237
# Epoch 52/200
# 58/58 [==============================] - 0s 7ms/step - loss: 4.4265e-04 - accuracy: 1.0000 - val_loss: 0.6221 - val_accuracy: 0.9253
# Epoch 53/200
# 58/58 [==============================] - 0s 7ms/step - loss: 6.2721e-04 - accuracy: 0.9997 - val_loss: 0.6573 - val_accuracy: 0.9260
# Epoch 54/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.8033e-04 - accuracy: 1.0000 - val_loss: 0.6492 - val_accuracy: 0.9267
# Epoch 55/200
# 58/58 [==============================] - 0s 8ms/step - loss: 1.9475e-04 - accuracy: 1.0000 - val_loss: 0.7224 - val_accuracy: 0.9220
# Epoch 56/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.8476e-04 - accuracy: 1.0000 - val_loss: 0.6108 - val_accuracy: 0.9253
# Epoch 57/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.7252 - val_accuracy: 0.9145
# Epoch 58/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0195 - accuracy: 0.9952 - val_loss: 0.4606 - val_accuracy: 0.9175
# Epoch 59/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.5127 - val_accuracy: 0.9233
# Epoch 60/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.4331 - val_accuracy: 0.9155
# Epoch 61/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.4596 - val_accuracy: 0.9237
# Epoch 62/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.4192 - val_accuracy: 0.9240
# Epoch 63/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.4724 - val_accuracy: 0.9203
# Epoch 64/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.4884 - val_accuracy: 0.9223
# Epoch 65/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.5902 - val_accuracy: 0.9148
# Epoch 66/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.5354 - val_accuracy: 0.9189
# Epoch 67/200
# 58/58 [==============================] - 0s 7ms/step - loss: 6.1010e-04 - accuracy: 1.0000 - val_loss: 0.6150 - val_accuracy: 0.9169
# Epoch 68/200
# 58/58 [==============================] - 0s 8ms/step - loss: 2.9823e-04 - accuracy: 1.0000 - val_loss: 0.5741 - val_accuracy: 0.9220
# Epoch 69/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.4886e-04 - accuracy: 1.0000 - val_loss: 0.5989 - val_accuracy: 0.9220
# Epoch 70/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.7542 - val_accuracy: 0.9040
# Epoch 71/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.5669 - val_accuracy: 0.9216
# Epoch 72/200
# 58/58 [==============================] - 0s 8ms/step - loss: 1.8612e-04 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.9206
# Epoch 73/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1032e-04 - accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.9196
# Epoch 74/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.7778e-04 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.9237
# Epoch 75/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.5876 - val_accuracy: 0.9230
# Epoch 76/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0245 - accuracy: 0.9929 - val_loss: 0.4761 - val_accuracy: 0.9220
# Epoch 77/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.5415 - val_accuracy: 0.9203
# Epoch 78/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.5797 - val_accuracy: 0.9223
# Epoch 79/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.6502 - val_accuracy: 0.9206
# Epoch 80/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.7294 - val_accuracy: 0.9158
# Epoch 81/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.5914 - val_accuracy: 0.9260
# Epoch 82/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.6206 - val_accuracy: 0.9274
# Epoch 83/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.6640 - val_accuracy: 0.9209
# Epoch 84/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.6892 - val_accuracy: 0.9192
# Epoch 85/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.6081 - val_accuracy: 0.9223
# Epoch 86/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.2230e-04 - accuracy: 1.0000 - val_loss: 0.6310 - val_accuracy: 0.9216
# Epoch 87/200
# 58/58 [==============================] - 0s 7ms/step - loss: 4.2879e-04 - accuracy: 0.9997 - val_loss: 0.5739 - val_accuracy: 0.9291
# Epoch 88/200
# 58/58 [==============================] - 0s 7ms/step - loss: 9.3853e-04 - accuracy: 0.9999 - val_loss: 0.7503 - val_accuracy: 0.9226
# Epoch 89/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.6956e-04 - accuracy: 1.0000 - val_loss: 0.8124 - val_accuracy: 0.9199
# Epoch 90/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.7321 - val_accuracy: 0.9141
# Epoch 91/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.5514 - val_accuracy: 0.9203
# Epoch 92/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.6065 - val_accuracy: 0.9196
# Epoch 93/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.6479 - val_accuracy: 0.9175
# Epoch 94/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.6354 - val_accuracy: 0.9172
# Epoch 95/200
# 58/58 [==============================] - 0s 8ms/step - loss: 7.7139e-04 - accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.9220
# Epoch 96/200
# 58/58 [==============================] - 0s 8ms/step - loss: 3.8510e-04 - accuracy: 1.0000 - val_loss: 0.6058 - val_accuracy: 0.9247
# Epoch 97/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.6934 - val_accuracy: 0.9158
# Epoch 98/200
# 58/58 [==============================] - 0s 7ms/step - loss: 9.3057e-04 - accuracy: 0.9996 - val_loss: 0.6957 - val_accuracy: 0.9220
# Epoch 99/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.7067 - val_accuracy: 0.9196
# Epoch 100/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.6560 - val_accuracy: 0.9209
# Epoch 101/200
# 58/58 [==============================] - 0s 7ms/step - loss: 9.7187e-05 - accuracy: 1.0000 - val_loss: 0.6650 - val_accuracy: 0.9237
# Epoch 102/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1052e-04 - accuracy: 1.0000 - val_loss: 0.7008 - val_accuracy: 0.9206
# Epoch 103/200
# 58/58 [==============================] - 0s 8ms/step - loss: 5.1106e-05 - accuracy: 1.0000 - val_loss: 0.7107 - val_accuracy: 0.9209
# Epoch 104/200
# 58/58 [==============================] - 0s 8ms/step - loss: 8.9473e-05 - accuracy: 1.0000 - val_loss: 0.7502 - val_accuracy: 0.9189
# Epoch 105/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.2076e-04 - accuracy: 1.0000 - val_loss: 0.7882 - val_accuracy: 0.9162
# Epoch 106/200
# 58/58 [==============================] - 0s 7ms/step - loss: 8.7216e-05 - accuracy: 1.0000 - val_loss: 0.8477 - val_accuracy: 0.9145
# Epoch 107/200
# 58/58 [==============================] - 0s 8ms/step - loss: 1.4606e-04 - accuracy: 1.0000 - val_loss: 0.8341 - val_accuracy: 0.9111
# Epoch 108/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 0.9982 - val_loss: 0.6617 - val_accuracy: 0.9172
# Epoch 109/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.9917 - val_loss: 0.5003 - val_accuracy: 0.9237
# Epoch 110/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.6169 - val_accuracy: 0.9220
# Epoch 111/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.6955 - val_accuracy: 0.9192
# Epoch 112/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.7665 - val_accuracy: 0.9165
# Epoch 113/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.7750 - val_accuracy: 0.9125
# Epoch 114/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.7492 - val_accuracy: 0.9158
# Epoch 115/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.6566 - val_accuracy: 0.9162
# Epoch 116/200
# 58/58 [==============================] - 0s 7ms/step - loss: 8.0458e-04 - accuracy: 1.0000 - val_loss: 0.7068 - val_accuracy: 0.9175
# Epoch 117/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.7135 - val_accuracy: 0.9114
# Epoch 118/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.7243 - val_accuracy: 0.9145
# Epoch 119/200
# 58/58 [==============================] - 0s 7ms/step - loss: 8.5094e-04 - accuracy: 0.9999 - val_loss: 0.7705 - val_accuracy: 0.9175
# Epoch 120/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5757e-04 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.9175
# Epoch 121/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.6755 - val_accuracy: 0.9213
# Epoch 122/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.7664 - val_accuracy: 0.9145
# Epoch 123/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.7034 - val_accuracy: 0.9206
# Epoch 124/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.7597 - val_accuracy: 0.9230
# Epoch 125/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.6742 - val_accuracy: 0.9165
# Epoch 126/200
# 58/58 [==============================] - 0s 7ms/step - loss: 7.6925e-04 - accuracy: 0.9997 - val_loss: 0.7220 - val_accuracy: 0.9172
# Epoch 127/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.7466 - val_accuracy: 0.9155
# Epoch 128/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.6303e-04 - accuracy: 1.0000 - val_loss: 0.7632 - val_accuracy: 0.9175
# Epoch 129/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.8182 - val_accuracy: 0.9125
# Epoch 130/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.6560 - val_accuracy: 0.9223
# Epoch 131/200
# 58/58 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.5874 - val_accuracy: 0.9257
# Epoch 132/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.5690 - val_accuracy: 0.9257
# Epoch 133/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.5953 - val_accuracy: 0.9216
# Epoch 134/200
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.6194 - val_accuracy: 0.9206
# Epoch 135/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.6106 - val_accuracy: 0.9253
# Epoch 136/200
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.6763 - val_accuracy: 0.9179
# Epoch 137/200
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.6655 - val_accuracy: 0.9264
# Epoch 138/200
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.6774 - val_accuracy: 0.9260
# Epoch 139/200
# 58/58 [==============================] - 1s 9ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.6252 - val_accuracy: 0.9213
# Epoch 140/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.6097 - val_accuracy: 0.9284
# Epoch 141/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.6249 - val_accuracy: 0.9287
# Epoch 142/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.6732 - val_accuracy: 0.9284
# Epoch 143/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.7852 - val_accuracy: 0.9125
# Epoch 144/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.5145 - val_accuracy: 0.9250
# Epoch 145/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.6662 - val_accuracy: 0.9186
# Epoch 146/200
# 58/58 [==============================] - 0s 7ms/step - loss: 4.4279e-04 - accuracy: 1.0000 - val_loss: 0.7089 - val_accuracy: 0.9203
# Epoch 147/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.5243e-04 - accuracy: 1.0000 - val_loss: 0.7192 - val_accuracy: 0.9213
# Epoch 148/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.4677e-04 - accuracy: 0.9999 - val_loss: 0.6599 - val_accuracy: 0.9243
# Epoch 149/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.3598e-04 - accuracy: 1.0000 - val_loss: 0.6847 - val_accuracy: 0.9247
# Epoch 150/200
# 58/58 [==============================] - 1s 9ms/step - loss: 9.1733e-05 - accuracy: 1.0000 - val_loss: 0.6948 - val_accuracy: 0.9260
# Epoch 151/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.2174e-04 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.9260
# Epoch 152/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.7901 - val_accuracy: 0.9094
# Epoch 153/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.6226 - val_accuracy: 0.9223
# Epoch 154/200
# 58/58 [==============================] - 0s 7ms/step - loss: 9.7750e-04 - accuracy: 0.9997 - val_loss: 0.5723 - val_accuracy: 0.9281
# Epoch 155/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.5037 - val_accuracy: 0.9216
# Epoch 156/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.4308 - val_accuracy: 0.9308
# Epoch 157/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.4552 - val_accuracy: 0.9298
# Epoch 158/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.4860 - val_accuracy: 0.9311
# Epoch 159/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.4533e-04 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.9304
# Epoch 160/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.1084e-04 - accuracy: 0.9997 - val_loss: 0.4945 - val_accuracy: 0.9294
# Epoch 161/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.5174e-04 - accuracy: 0.9999 - val_loss: 0.5401 - val_accuracy: 0.9294
# Epoch 162/200
# 58/58 [==============================] - 0s 7ms/step - loss: 7.3198e-04 - accuracy: 0.9997 - val_loss: 0.5426 - val_accuracy: 0.9274
# Epoch 163/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.5442 - val_accuracy: 0.9298
# Epoch 164/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.9817e-04 - accuracy: 0.9999 - val_loss: 0.5369 - val_accuracy: 0.9308
# Epoch 165/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.3350e-04 - accuracy: 1.0000 - val_loss: 0.5530 - val_accuracy: 0.9315
# Epoch 166/200
# 58/58 [==============================] - 0s 7ms/step - loss: 4.5784e-04 - accuracy: 0.9997 - val_loss: 0.5679 - val_accuracy: 0.9298
# Epoch 167/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.5744 - val_accuracy: 0.9294
# Epoch 168/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.5173 - val_accuracy: 0.9230
# Epoch 169/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.4855 - val_accuracy: 0.9294
# Epoch 170/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.5476 - val_accuracy: 0.9230
# Epoch 171/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.5486 - val_accuracy: 0.9247
# Epoch 172/200
# 58/58 [==============================] - 0s 7ms/step - loss: 5.3527e-04 - accuracy: 0.9999 - val_loss: 0.5451 - val_accuracy: 0.9270
# Epoch 173/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.6349e-04 - accuracy: 1.0000 - val_loss: 0.6010 - val_accuracy: 0.9257
# Epoch 174/200
# 58/58 [==============================] - 0s 9ms/step - loss: 2.2192e-04 - accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.9301
# Epoch 175/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.6244 - val_accuracy: 0.9253
# Epoch 176/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.4433 - val_accuracy: 0.9325
# Epoch 177/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.4764 - val_accuracy: 0.9376
# Epoch 178/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.4632 - val_accuracy: 0.9393
# Epoch 179/200
# 58/58 [==============================] - 0s 7ms/step - loss: 8.3227e-04 - accuracy: 0.9999 - val_loss: 0.5016 - val_accuracy: 0.9386
# Epoch 180/200
# 58/58 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.6475 - val_accuracy: 0.9257
# Epoch 181/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.5254 - val_accuracy: 0.9291
# Epoch 182/200
# 58/58 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.5501 - val_accuracy: 0.9301
# Epoch 183/200
# 58/58 [==============================] - 0s 7ms/step - loss: 4.7673e-04 - accuracy: 1.0000 - val_loss: 0.6521 - val_accuracy: 0.9287
# Epoch 184/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.5737e-04 - accuracy: 0.9999 - val_loss: 0.6552 - val_accuracy: 0.9294
# Epoch 185/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.3348e-04 - accuracy: 1.0000 - val_loss: 0.6248 - val_accuracy: 0.9284
# Epoch 186/200
# 58/58 [==============================] - 0s 7ms/step - loss: 8.2586e-05 - accuracy: 1.0000 - val_loss: 0.6245 - val_accuracy: 0.9298
# Epoch 187/200
# 58/58 [==============================] - 1s 9ms/step - loss: 7.8994e-05 - accuracy: 1.0000 - val_loss: 0.6184 - val_accuracy: 0.9308
# Epoch 188/200
# 58/58 [==============================] - 0s 8ms/step - loss: 7.5239e-05 - accuracy: 1.0000 - val_loss: 0.6235 - val_accuracy: 0.9308
# Epoch 189/200
# 58/58 [==============================] - 0s 8ms/step - loss: 5.6504e-05 - accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.9311
# Epoch 190/200
# 58/58 [==============================] - 0s 8ms/step - loss: 5.8117e-05 - accuracy: 1.0000 - val_loss: 0.6368 - val_accuracy: 0.9315
# Epoch 191/200
# 58/58 [==============================] - 0s 8ms/step - loss: 4.1236e-05 - accuracy: 1.0000 - val_loss: 0.6388 - val_accuracy: 0.9315
# Epoch 192/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.4222e-05 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.9315
# Epoch 193/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.7004e-05 - accuracy: 1.0000 - val_loss: 0.6493 - val_accuracy: 0.9315
# Epoch 194/200
# 58/58 [==============================] - 0s 7ms/step - loss: 2.7377e-05 - accuracy: 1.0000 - val_loss: 0.6455 - val_accuracy: 0.9311
# Epoch 195/200
# 58/58 [==============================] - 0s 7ms/step - loss: 9.1369e-05 - accuracy: 1.0000 - val_loss: 0.7687 - val_accuracy: 0.9243
# Epoch 196/200
# 58/58 [==============================] - 0s 8ms/step - loss: 4.4079e-05 - accuracy: 1.0000 - val_loss: 0.5974 - val_accuracy: 0.9352
# Epoch 197/200
# 58/58 [==============================] - 0s 9ms/step - loss: 1.9444e-05 - accuracy: 1.0000 - val_loss: 0.5994 - val_accuracy: 0.9352
# Epoch 198/200
# 58/58 [==============================] - 0s 8ms/step - loss: 2.7771e-05 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.9355
# Epoch 199/200
# 58/58 [==============================] - 0s 8ms/step - loss: 2.4438e-05 - accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.9355
# Epoch 200/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.0376e-05 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.9362
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:02:21.996898
#
#
# Predicting test data
# 93/93 [==============================] - 0s 3ms/step
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.350908
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9362063115032236
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[469   0  27   0   0   0]
#  [  1 453  17   0   0   0]
#  [  4   2 414   0   0   0]
#  [  0   3   0 400  84   4]
#  [  0   1   0  44 487   0]
#  [  0   1   0   0   0 536]]
# -------------------------
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       496
#            1       0.98      0.96      0.97       471
#            2       0.90      0.99      0.94       420
#            3       0.90      0.81      0.86       491
#            4       0.85      0.92      0.88       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.94      2947
#    macro avg       0.94      0.94      0.94      2947
# weighted avg       0.94      0.94      0.94      2947

# %%
EPOCHS=500

import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

kf = KFold(5, shuffle=True, random_state=42) 
    
oos_y = []
oos_pred = []
fold = 0
x = X_train
y = Y_train

# Must specify y StratifiedKFold for
for train, test in kf.split(x):  
    fold+=1
    print(f"Fold #{fold}")
        
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]
    model = Sequential()

    model.add(
        tf.keras.layers.TimeDistributed(
            tf.keras.layers.Conv1D(
                filters=128, kernel_size=6,strides=2,
                activation="relu",
                input_shape=(n_length, n_features)
            )
        )
    )

    model.add(
        tf.keras.layers.TimeDistributed(
          tf.keras.layers.MaxPool1D(pool_size=2, strides=2)
        )
    )



    model.add(
        tf.keras.layers.TimeDistributed(
            tf.keras.layers.Conv1DTranspose(
                filters=128, kernel_size=6,strides=2,
                activation="relu"
            )
        )
    )


    model.add(
        tf.keras.layers.TimeDistributed(
            tf.keras.layers.Flatten()
        ) 
    )

    model.add(Dropout(0.5))

    model.add(LSTM(64))


    # Adding a dense layer with relu activation
    model.add(Dense(64, activation='relu'))

    # Adding a dense layer with relu activation
    model.add(Dense(64, activation='relu'))

    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    model.fit(x_train,y_train, batch_size=128, validation_data=(x_test,y_test),verbose=1,
              epochs=EPOCHS)
    
    pred = model.predict(x_test)
    
    oos_y.append(y_test)
    oos_pred.append(pred)    

    # Measure this fold's accuracy
    score = model.evaluate(x_test,y_test)
    print(f"Fold score (Accuracy): {score}")

# Build the oos prediction list and calculate the error.
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
score = metrics.accuracy_score(np.argmax(oos_pred,axis=1),np.argmax(oos_y,axis=1))
print(f"Final, out of sample score (Accuracy): {score}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 11/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0918 - accuracy: 0.9611 - val_loss: 0.0914 - val_accuracy: 0.9579
# Epoch 12/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.1084 - accuracy: 0.9527 - val_loss: 0.0992 - val_accuracy: 0.9483
# Epoch 13/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0890 - accuracy: 0.9595 - val_loss: 0.0819 - val_accuracy: 0.9626
# Epoch 14/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0906 - accuracy: 0.9600 - val_loss: 0.0856 - val_accuracy: 0.9592
# Epoch 15/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0791 - accuracy: 0.9628 - val_loss: 0.0792 - val_accuracy: 0.9613
# Epoch 16/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0738 - accuracy: 0.9634 - val_loss: 0.0753 - val_accuracy: 0.9633
# Epoch 17/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0795 - accuracy: 0.9611 - val_loss: 0.0896 - val_accuracy: 0.9613
# Epoch 18/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0790 - accuracy: 0.9623 - val_loss: 0.0662 - val_accuracy: 0.9653
# Epoch 19/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0690 - accuracy: 0.9655 - val_loss: 0.0721 - val_accuracy: 0.9613
# Epoch 20/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0696 - accuracy: 0.9643 - val_loss: 0.0694 - val_accuracy: 0.9626
# Epoch 21/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0697 - accuracy: 0.9648 - val_loss: 0.0959 - val_accuracy: 0.9531
# Epoch 22/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.1202 - accuracy: 0.9519 - val_loss: 0.0791 - val_accuracy: 0.9619
# Epoch 23/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0678 - accuracy: 0.9648 - val_loss: 0.0762 - val_accuracy: 0.9606
# Epoch 24/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0590 - accuracy: 0.9696 - val_loss: 0.0607 - val_accuracy: 0.9680
# Epoch 25/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0629 - accuracy: 0.9665 - val_loss: 0.0644 - val_accuracy: 0.9633
# Epoch 26/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0567 - accuracy: 0.9702 - val_loss: 0.0572 - val_accuracy: 0.9762
# Epoch 27/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0561 - accuracy: 0.9740 - val_loss: 0.0578 - val_accuracy: 0.9653
# Epoch 28/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0584 - accuracy: 0.9702 - val_loss: 0.0704 - val_accuracy: 0.9687
# Epoch 29/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0528 - accuracy: 0.9728 - val_loss: 0.0648 - val_accuracy: 0.9653
# Epoch 30/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0534 - accuracy: 0.9728 - val_loss: 0.0691 - val_accuracy: 0.9714
# Epoch 31/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0530 - accuracy: 0.9742 - val_loss: 0.0599 - val_accuracy: 0.9680
# Epoch 32/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0519 - accuracy: 0.9738 - val_loss: 0.0568 - val_accuracy: 0.9694
# Epoch 33/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0483 - accuracy: 0.9753 - val_loss: 0.0678 - val_accuracy: 0.9585
# Epoch 34/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0523 - accuracy: 0.9736 - val_loss: 0.0649 - val_accuracy: 0.9708
# Epoch 35/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0454 - accuracy: 0.9769 - val_loss: 0.0563 - val_accuracy: 0.9701
# Epoch 36/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0431 - accuracy: 0.9769 - val_loss: 0.0704 - val_accuracy: 0.9667
# Epoch 37/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0504 - accuracy: 0.9745 - val_loss: 0.0526 - val_accuracy: 0.9755
# Epoch 38/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0447 - accuracy: 0.9765 - val_loss: 0.0466 - val_accuracy: 0.9762
# Epoch 39/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0433 - accuracy: 0.9767 - val_loss: 0.0601 - val_accuracy: 0.9735
# Epoch 40/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0488 - accuracy: 0.9743 - val_loss: 0.0509 - val_accuracy: 0.9728
# Epoch 41/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0473 - accuracy: 0.9781 - val_loss: 0.0566 - val_accuracy: 0.9714
# Epoch 42/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0586 - accuracy: 0.9731 - val_loss: 0.0606 - val_accuracy: 0.9755
# Epoch 43/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0450 - accuracy: 0.9772 - val_loss: 0.0597 - val_accuracy: 0.9680
# Epoch 44/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0459 - accuracy: 0.9806 - val_loss: 0.0399 - val_accuracy: 0.9830
# Epoch 45/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0404 - accuracy: 0.9803 - val_loss: 0.0478 - val_accuracy: 0.9776
# Epoch 46/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0385 - accuracy: 0.9796 - val_loss: 0.0482 - val_accuracy: 0.9782
# Epoch 47/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0394 - accuracy: 0.9810 - val_loss: 0.0765 - val_accuracy: 0.9742
# Epoch 48/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0477 - accuracy: 0.9779 - val_loss: 0.0532 - val_accuracy: 0.9830
# Epoch 49/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0464 - accuracy: 0.9801 - val_loss: 0.1010 - val_accuracy: 0.9592
# Epoch 50/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0493 - accuracy: 0.9750 - val_loss: 0.0532 - val_accuracy: 0.9728
# Epoch 51/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0338 - accuracy: 0.9842 - val_loss: 0.0385 - val_accuracy: 0.9810
# Epoch 52/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0256 - accuracy: 0.9878 - val_loss: 0.0396 - val_accuracy: 0.9803
# Epoch 53/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0398 - accuracy: 0.9806 - val_loss: 0.0487 - val_accuracy: 0.9776
# Epoch 54/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0270 - accuracy: 0.9866 - val_loss: 0.0376 - val_accuracy: 0.9857
# Epoch 55/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0274 - accuracy: 0.9879 - val_loss: 0.0589 - val_accuracy: 0.9742
# Epoch 56/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0557 - accuracy: 0.9774 - val_loss: 0.0540 - val_accuracy: 0.9755
# Epoch 57/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0358 - accuracy: 0.9844 - val_loss: 0.0501 - val_accuracy: 0.9782
# Epoch 58/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0293 - accuracy: 0.9857 - val_loss: 0.0289 - val_accuracy: 0.9878
# Epoch 59/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0262 - accuracy: 0.9881 - val_loss: 0.0404 - val_accuracy: 0.9844
# Epoch 60/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0245 - accuracy: 0.9874 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 61/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0204 - accuracy: 0.9912 - val_loss: 0.0263 - val_accuracy: 0.9918
# Epoch 62/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0224 - accuracy: 0.9910 - val_loss: 0.0407 - val_accuracy: 0.9850
# Epoch 63/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0254 - accuracy: 0.9878 - val_loss: 0.0285 - val_accuracy: 0.9884
# Epoch 64/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0395 - accuracy: 0.9857 - val_loss: 0.0462 - val_accuracy: 0.9857
# Epoch 65/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0322 - accuracy: 0.9871 - val_loss: 0.0393 - val_accuracy: 0.9864
# Epoch 66/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0235 - accuracy: 0.9891 - val_loss: 0.0286 - val_accuracy: 0.9939
# Epoch 67/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0282 - accuracy: 0.9881 - val_loss: 0.0348 - val_accuracy: 0.9850
# Epoch 68/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0299 - accuracy: 0.9872 - val_loss: 0.0364 - val_accuracy: 0.9857
# Epoch 69/500
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0187 - accuracy: 0.9910 - val_loss: 0.0275 - val_accuracy: 0.9905
# Epoch 70/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0191 - accuracy: 0.9915 - val_loss: 0.0502 - val_accuracy: 0.9782
# Epoch 71/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0390 - accuracy: 0.9850 - val_loss: 0.0362 - val_accuracy: 0.9857
# Epoch 72/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.9913 - val_loss: 0.0304 - val_accuracy: 0.9864
# Epoch 73/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.9896 - val_loss: 0.0256 - val_accuracy: 0.9905
# Epoch 74/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.9920 - val_loss: 0.0207 - val_accuracy: 0.9905
# Epoch 75/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 0.9910 - val_loss: 0.0402 - val_accuracy: 0.9878
# Epoch 76/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0234 - accuracy: 0.9901 - val_loss: 0.0392 - val_accuracy: 0.9844
# Epoch 77/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.9917 - val_loss: 0.0296 - val_accuracy: 0.9864
# Epoch 78/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0148 - accuracy: 0.9934 - val_loss: 0.0260 - val_accuracy: 0.9912
# Epoch 79/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 0.9956 - val_loss: 0.0250 - val_accuracy: 0.9912
# Epoch 80/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0148 - accuracy: 0.9937 - val_loss: 0.0252 - val_accuracy: 0.9912
# Epoch 81/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0170 - accuracy: 0.9925 - val_loss: 0.0332 - val_accuracy: 0.9871
# Epoch 82/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.9913 - val_loss: 0.0263 - val_accuracy: 0.9912
# Epoch 83/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0161 - accuracy: 0.9925 - val_loss: 0.0618 - val_accuracy: 0.9796
# Epoch 84/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.9906 - val_loss: 0.0269 - val_accuracy: 0.9918
# Epoch 85/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0132 - accuracy: 0.9944 - val_loss: 0.0209 - val_accuracy: 0.9912
# Epoch 86/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0139 - accuracy: 0.9930 - val_loss: 0.0521 - val_accuracy: 0.9782
# Epoch 87/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0248 - accuracy: 0.9888 - val_loss: 0.0394 - val_accuracy: 0.9905
# Epoch 88/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 0.0260 - val_accuracy: 0.9939
# Epoch 89/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0289 - val_accuracy: 0.9925
# Epoch 90/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0570 - val_accuracy: 0.9830
# Epoch 91/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0148 - accuracy: 0.9937 - val_loss: 0.0456 - val_accuracy: 0.9871
# Epoch 92/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0249 - accuracy: 0.9912 - val_loss: 0.0365 - val_accuracy: 0.9864
# Epoch 93/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0169 - accuracy: 0.9935 - val_loss: 0.0298 - val_accuracy: 0.9912
# Epoch 94/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0218 - val_accuracy: 0.9939
# Epoch 95/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0181 - accuracy: 0.9925 - val_loss: 0.0678 - val_accuracy: 0.9816
# Epoch 96/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0265 - accuracy: 0.9886 - val_loss: 0.0529 - val_accuracy: 0.9823
# Epoch 97/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0275 - accuracy: 0.9906 - val_loss: 0.0294 - val_accuracy: 0.9878
# Epoch 98/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0351 - val_accuracy: 0.9864
# Epoch 99/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.0271 - val_accuracy: 0.9918
# Epoch 100/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0187 - accuracy: 0.9925 - val_loss: 0.0398 - val_accuracy: 0.9864
# Epoch 101/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0101 - accuracy: 0.9954 - val_loss: 0.0435 - val_accuracy: 0.9878
# Epoch 102/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0109 - accuracy: 0.9947 - val_loss: 0.0372 - val_accuracy: 0.9878
# Epoch 103/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0309 - val_accuracy: 0.9925
# Epoch 104/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0395 - val_accuracy: 0.9857
# Epoch 105/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0280 - val_accuracy: 0.9918
# Epoch 106/500
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0078 - accuracy: 0.9963 - val_loss: 0.0539 - val_accuracy: 0.9864
# Epoch 107/500
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0437 - accuracy: 0.9845 - val_loss: 0.0495 - val_accuracy: 0.9844
# Epoch 108/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0271 - val_accuracy: 0.9912
# Epoch 109/500
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0260 - val_accuracy: 0.9925
# Epoch 110/500
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0079 - accuracy: 0.9963 - val_loss: 0.0258 - val_accuracy: 0.9925
# Epoch 111/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0314 - val_accuracy: 0.9918
# Epoch 112/500
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.0506 - val_accuracy: 0.9844
# Epoch 113/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0187 - accuracy: 0.9932 - val_loss: 0.0347 - val_accuracy: 0.9857
# Epoch 114/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 0.0306 - val_accuracy: 0.9891
# Epoch 115/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0305 - val_accuracy: 0.9878
# Epoch 116/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0078 - accuracy: 0.9964 - val_loss: 0.0358 - val_accuracy: 0.9884
# Epoch 117/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0118 - accuracy: 0.9949 - val_loss: 0.0251 - val_accuracy: 0.9925
# Epoch 118/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0153 - accuracy: 0.9940 - val_loss: 0.0321 - val_accuracy: 0.9905
# Epoch 119/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0080 - accuracy: 0.9959 - val_loss: 0.0354 - val_accuracy: 0.9878
# Epoch 120/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0271 - val_accuracy: 0.9905
# Epoch 121/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.9944 - val_loss: 0.0462 - val_accuracy: 0.9850
# Epoch 122/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0391 - val_accuracy: 0.9871
# Epoch 123/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0130 - accuracy: 0.9940 - val_loss: 0.0271 - val_accuracy: 0.9891
# Epoch 124/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0134 - accuracy: 0.9944 - val_loss: 0.0280 - val_accuracy: 0.9918
# Epoch 125/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0265 - val_accuracy: 0.9918
# Epoch 126/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.0241 - val_accuracy: 0.9932
# Epoch 127/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.0284 - val_accuracy: 0.9925
# Epoch 128/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0263 - val_accuracy: 0.9925
# Epoch 129/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.0260 - val_accuracy: 0.9925
# Epoch 130/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0276 - val_accuracy: 0.9925
# Epoch 131/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0309 - val_accuracy: 0.9925
# Epoch 132/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0771 - val_accuracy: 0.9850
# Epoch 133/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0361 - accuracy: 0.9874 - val_loss: 0.0317 - val_accuracy: 0.9864
# Epoch 134/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0257 - val_accuracy: 0.9905
# Epoch 135/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0241 - val_accuracy: 0.9932
# Epoch 136/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0241 - val_accuracy: 0.9932
# Epoch 137/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0304 - val_accuracy: 0.9898
# Epoch 138/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0347 - val_accuracy: 0.9905
# Epoch 139/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.0294 - val_accuracy: 0.9918
# Epoch 140/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.0339 - val_accuracy: 0.9871
# Epoch 141/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0223 - val_accuracy: 0.9939
# Epoch 142/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0186 - val_accuracy: 0.9925
# Epoch 143/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0312 - val_accuracy: 0.9905
# Epoch 144/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0237 - val_accuracy: 0.9932
# Epoch 145/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.0435 - val_accuracy: 0.9837
# Epoch 146/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0687 - val_accuracy: 0.9762
# Epoch 147/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.0233 - val_accuracy: 0.9925
# Epoch 148/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0240 - val_accuracy: 0.9932
# Epoch 149/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0203 - val_accuracy: 0.9932
# Epoch 150/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0226 - val_accuracy: 0.9939
# Epoch 151/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0263 - val_accuracy: 0.9932
# Epoch 152/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0235 - val_accuracy: 0.9939
# Epoch 153/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 0.9980 - val_loss: 0.0256 - val_accuracy: 0.9918
# Epoch 154/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0249 - val_accuracy: 0.9939
# Epoch 155/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0253 - val_accuracy: 0.9932
# Epoch 156/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 0.0237 - val_accuracy: 0.9932
# Epoch 157/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0247 - val_accuracy: 0.9932
# Epoch 158/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0261 - val_accuracy: 0.9946
# Epoch 159/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0278 - val_accuracy: 0.9925
# Epoch 160/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0257 - accuracy: 0.9932 - val_loss: 0.0277 - val_accuracy: 0.9925
# Epoch 161/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.0204 - val_accuracy: 0.9952
# Epoch 162/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 163/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0298 - val_accuracy: 0.9898
# Epoch 164/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0313 - val_accuracy: 0.9905
# Epoch 165/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0256 - val_accuracy: 0.9925
# Epoch 166/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 0.9959 - val_loss: 0.0314 - val_accuracy: 0.9912
# Epoch 167/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0350 - val_accuracy: 0.9898
# Epoch 168/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0282 - val_accuracy: 0.9932
# Epoch 169/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0321 - val_accuracy: 0.9925
# Epoch 170/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0367 - val_accuracy: 0.9918
# Epoch 171/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0842 - val_accuracy: 0.9789
# Epoch 172/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0283 - val_accuracy: 0.9912
# Epoch 173/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0283 - val_accuracy: 0.9912
# Epoch 174/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0291 - val_accuracy: 0.9925
# Epoch 175/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0309 - val_accuracy: 0.9918
# Epoch 176/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9974 - val_loss: 0.0332 - val_accuracy: 0.9918
# Epoch 177/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0413 - val_accuracy: 0.9891
# Epoch 178/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0575 - val_accuracy: 0.9837
# Epoch 179/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.0299 - val_accuracy: 0.9925
# Epoch 180/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.0459 - val_accuracy: 0.9871
# Epoch 181/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.0369 - val_accuracy: 0.9905
# Epoch 182/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.0240 - val_accuracy: 0.9946
# Epoch 183/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0270 - val_accuracy: 0.9932
# Epoch 184/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0327 - val_accuracy: 0.9925
# Epoch 185/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 0.9988 - val_loss: 0.0294 - val_accuracy: 0.9939
# Epoch 186/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0328 - val_accuracy: 0.9939
# Epoch 187/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0314 - val_accuracy: 0.9946
# Epoch 188/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0325 - val_accuracy: 0.9939
# Epoch 189/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0327 - val_accuracy: 0.9939
# Epoch 190/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9988 - val_loss: 0.0377 - val_accuracy: 0.9932
# Epoch 191/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0335 - val_accuracy: 0.9946
# Epoch 192/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.0844 - val_accuracy: 0.9837
# Epoch 193/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0434 - accuracy: 0.9918 - val_loss: 0.0789 - val_accuracy: 0.9823
# Epoch 194/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0339 - val_accuracy: 0.9898
# Epoch 195/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0365 - val_accuracy: 0.9884
# Epoch 196/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0129 - accuracy: 0.9952 - val_loss: 0.0300 - val_accuracy: 0.9925
# Epoch 197/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0236 - val_accuracy: 0.9932
# Epoch 198/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.0212 - val_accuracy: 0.9952
# Epoch 199/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0246 - val_accuracy: 0.9952
# Epoch 200/500
# 46/46 [==============================] - 0s 9ms/step - loss: 8.2388e-04 - accuracy: 0.9998 - val_loss: 0.0241 - val_accuracy: 0.9959
# Epoch 201/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0227 - val_accuracy: 0.9952
# Epoch 202/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0372 - val_accuracy: 0.9912
# Epoch 203/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0386 - val_accuracy: 0.9912
# Epoch 204/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 0.0424 - val_accuracy: 0.9898
# Epoch 205/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0336 - val_accuracy: 0.9905
# Epoch 206/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0470 - val_accuracy: 0.9857
# Epoch 207/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0321 - val_accuracy: 0.9905
# Epoch 208/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0278 - val_accuracy: 0.9925
# Epoch 209/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0335 - val_accuracy: 0.9905
# Epoch 210/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0255 - val_accuracy: 0.9952
# Epoch 211/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0300 - val_accuracy: 0.9932
# Epoch 212/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0306 - val_accuracy: 0.9918
# Epoch 213/500
# 46/46 [==============================] - 0s 8ms/step - loss: 6.7593e-04 - accuracy: 0.9998 - val_loss: 0.0269 - val_accuracy: 0.9952
# Epoch 214/500
# 46/46 [==============================] - 0s 8ms/step - loss: 6.2239e-04 - accuracy: 0.9998 - val_loss: 0.0289 - val_accuracy: 0.9952
# Epoch 215/500
# 46/46 [==============================] - 0s 9ms/step - loss: 2.4975e-04 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9952
# Epoch 216/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0442 - val_accuracy: 0.9918
# Epoch 217/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0454 - val_accuracy: 0.9850
# Epoch 218/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0179 - accuracy: 0.9932 - val_loss: 0.0307 - val_accuracy: 0.9912
# Epoch 219/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.0321 - val_accuracy: 0.9912
# Epoch 220/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.0309 - val_accuracy: 0.9932
# Epoch 221/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0311 - val_accuracy: 0.9932
# Epoch 222/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0308 - val_accuracy: 0.9932
# Epoch 223/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 0.9988 - val_loss: 0.0330 - val_accuracy: 0.9925
# Epoch 224/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0382 - val_accuracy: 0.9891
# Epoch 225/500
# 46/46 [==============================] - 0s 8ms/step - loss: 8.2283e-04 - accuracy: 0.9997 - val_loss: 0.0342 - val_accuracy: 0.9925
# Epoch 226/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0318 - val_accuracy: 0.9912
# Epoch 227/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0367 - val_accuracy: 0.9912
# Epoch 228/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9988 - val_loss: 0.0316 - val_accuracy: 0.9939
# Epoch 229/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0520 - val_accuracy: 0.9864
# Epoch 230/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0400 - val_accuracy: 0.9925
# Epoch 231/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0353 - val_accuracy: 0.9939
# Epoch 232/500
# 46/46 [==============================] - 0s 8ms/step - loss: 5.3242e-04 - accuracy: 0.9998 - val_loss: 0.0401 - val_accuracy: 0.9932
# Epoch 233/500
# 46/46 [==============================] - 0s 9ms/step - loss: 4.7759e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9946
# Epoch 234/500
# 46/46 [==============================] - 0s 8ms/step - loss: 2.5840e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9946
# Epoch 235/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.8169e-04 - accuracy: 0.9997 - val_loss: 0.0375 - val_accuracy: 0.9932
# Epoch 236/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0606 - val_accuracy: 0.9864
# Epoch 237/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0426 - val_accuracy: 0.9871
# Epoch 238/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0306 - val_accuracy: 0.9912
# Epoch 239/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.0394 - val_accuracy: 0.9905
# Epoch 240/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0309 - val_accuracy: 0.9918
# Epoch 241/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 242/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.0172 - val_accuracy: 0.9952
# Epoch 243/500
# 46/46 [==============================] - 0s 8ms/step - loss: 8.7775e-04 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9918
# Epoch 244/500
# 46/46 [==============================] - 0s 9ms/step - loss: 3.8076e-04 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9925
# Epoch 245/500
# 46/46 [==============================] - 0s 9ms/step - loss: 2.1641e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9939
# Epoch 246/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.7167e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9939
# Epoch 247/500
# 46/46 [==============================] - 0s 8ms/step - loss: 1.7048e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9939
# Epoch 248/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0711 - val_accuracy: 0.9830
# Epoch 249/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0308 - val_accuracy: 0.9905
# Epoch 250/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0325 - val_accuracy: 0.9939
# Epoch 251/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0466 - val_accuracy: 0.9878
# Epoch 252/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0267 - val_accuracy: 0.9898
# Epoch 253/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0260 - val_accuracy: 0.9918
# Epoch 254/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0343 - val_accuracy: 0.9898
# Epoch 255/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0353 - val_accuracy: 0.9905
# Epoch 256/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0270 - val_accuracy: 0.9912
# Epoch 257/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0367 - val_accuracy: 0.9918
# Epoch 258/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.9852e-04 - accuracy: 0.9998 - val_loss: 0.0280 - val_accuracy: 0.9939
# Epoch 259/500
# 46/46 [==============================] - 0s 9ms/step - loss: 3.1251e-04 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9952
# Epoch 260/500
# 46/46 [==============================] - 0s 8ms/step - loss: 1.7393e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9925
# Epoch 261/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.8996e-04 - accuracy: 0.9998 - val_loss: 0.0267 - val_accuracy: 0.9952
# Epoch 262/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0230 - val_accuracy: 0.9939
# Epoch 263/500
# 46/46 [==============================] - 0s 9ms/step - loss: 4.0973e-04 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9939
# Epoch 264/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.8033e-04 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9918
# Epoch 265/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.5374e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9939
# Epoch 266/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.5272e-04 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9946
# Epoch 267/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.2877e-05 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9939
# Epoch 268/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.2432e-04 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9932
# Epoch 269/500
# 46/46 [==============================] - 0s 9ms/step - loss: 6.3200e-05 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9939
# Epoch 270/500
# 46/46 [==============================] - 0s 9ms/step - loss: 7.8145e-05 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9939
# Epoch 271/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.0920 - val_accuracy: 0.9823
# Epoch 272/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0277 - val_accuracy: 0.9898
# Epoch 273/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0331 - val_accuracy: 0.9918
# Epoch 274/500
# 46/46 [==============================] - 0s 9ms/step - loss: 7.8541e-04 - accuracy: 0.9998 - val_loss: 0.0276 - val_accuracy: 0.9946
# Epoch 275/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.2547e-04 - accuracy: 0.9998 - val_loss: 0.0312 - val_accuracy: 0.9932
# Epoch 276/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0376 - val_accuracy: 0.9878
# Epoch 277/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0257 - val_accuracy: 0.9898
# Epoch 278/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0255 - val_accuracy: 0.9912
# Epoch 279/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0211 - val_accuracy: 0.9952
# Epoch 280/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0337 - val_accuracy: 0.9918
# Epoch 281/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0377 - val_accuracy: 0.9905
# Epoch 282/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0311 - val_accuracy: 0.9939
# Epoch 283/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.9986 - val_loss: 0.0562 - val_accuracy: 0.9864
# Epoch 284/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0126 - accuracy: 0.9973 - val_loss: 0.0594 - val_accuracy: 0.9884
# Epoch 285/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0341 - val_accuracy: 0.9891
# Epoch 286/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0398 - val_accuracy: 0.9905
# Epoch 287/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0368 - val_accuracy: 0.9918
# Epoch 288/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0380 - val_accuracy: 0.9925
# Epoch 289/500
# 46/46 [==============================] - 0s 9ms/step - loss: 4.6729e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9925
# Epoch 290/500
# 46/46 [==============================] - 0s 9ms/step - loss: 8.3135e-04 - accuracy: 0.9998 - val_loss: 0.0359 - val_accuracy: 0.9932
# Epoch 291/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0306 - val_accuracy: 0.9925
# Epoch 292/500
# 46/46 [==============================] - 0s 9ms/step - loss: 3.9926e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9912
# Epoch 293/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0418 - val_accuracy: 0.9905
# Epoch 294/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0412 - val_accuracy: 0.9905
# Epoch 295/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.1922e-04 - accuracy: 0.9998 - val_loss: 0.0387 - val_accuracy: 0.9912
# Epoch 296/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0493 - val_accuracy: 0.9891
# Epoch 297/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 0.0434 - val_accuracy: 0.9918
# Epoch 298/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0470 - val_accuracy: 0.9905
# Epoch 299/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0409 - val_accuracy: 0.9891
# Epoch 300/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0323 - val_accuracy: 0.9932
# Epoch 301/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.0347 - val_accuracy: 0.9912
# Epoch 302/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0363 - val_accuracy: 0.9918
# Epoch 303/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0396 - val_accuracy: 0.9905
# Epoch 304/500
# 46/46 [==============================] - 0s 9ms/step - loss: 2.1412e-04 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9925
# Epoch 305/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.2273e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9939
# Epoch 306/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.4672e-04 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9912
# Epoch 307/500
# 46/46 [==============================] - 0s 10ms/step - loss: 7.7806e-05 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9939
# Epoch 308/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0510 - val_accuracy: 0.9925
# Epoch 309/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0510 - val_accuracy: 0.9905
# Epoch 310/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0609 - val_accuracy: 0.9864
# Epoch 311/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0396 - val_accuracy: 0.9884
# Epoch 312/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0335 - val_accuracy: 0.9912
# Epoch 313/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0400 - val_accuracy: 0.9891
# Epoch 314/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0371 - val_accuracy: 0.9891
# Epoch 315/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0293 - val_accuracy: 0.9918
# Epoch 316/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0507 - val_accuracy: 0.9844
# Epoch 317/500
# 46/46 [==============================] - 0s 9ms/step - loss: 6.6671e-04 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9925
# Epoch 318/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.9173e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9932
# Epoch 319/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.6139e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9932
# Epoch 320/500
# 46/46 [==============================] - 0s 9ms/step - loss: 1.0169e-04 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9932
# Epoch 321/500
# 46/46 [==============================] - 0s 9ms/step - loss: 8.8964e-05 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9939
# Epoch 322/500
# 46/46 [==============================] - 0s 9ms/step - loss: 7.6320e-05 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9932
# Epoch 323/500
# 46/46 [==============================] - 0s 9ms/step - loss: 6.3654e-05 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9932
# Epoch 324/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.2137e-05 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9939
# Epoch 325/500
# 46/46 [==============================] - 0s 9ms/step - loss: 3.6634e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9939
# Epoch 326/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0403 - val_accuracy: 0.9918
# Epoch 327/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0375 - val_accuracy: 0.9925
# Epoch 328/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0460 - val_accuracy: 0.9918
# Epoch 329/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0230 - accuracy: 0.9942 - val_loss: 0.0342 - val_accuracy: 0.9891
# Epoch 330/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0410 - val_accuracy: 0.9891
# Epoch 331/500
# 46/46 [==============================] - 0s 9ms/step - loss: 6.5350e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9905
# Epoch 332/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0553 - val_accuracy: 0.9891
# Epoch 333/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0355 - val_accuracy: 0.9891
# Epoch 334/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0316 - val_accuracy: 0.9939
# Epoch 335/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0403 - val_accuracy: 0.9905
# Epoch 336/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0453 - val_accuracy: 0.9912
# Epoch 337/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0453 - val_accuracy: 0.9905
# Epoch 338/500
# 46/46 [==============================] - 0s 9ms/step - loss: 7.4942e-04 - accuracy: 0.9998 - val_loss: 0.0448 - val_accuracy: 0.9898
# Epoch 339/500
# 46/46 [==============================] - 0s 9ms/step - loss: 5.0834e-04 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9912
# Epoch 340/500
# 46/46 [==============================] - 0s 9ms/step - loss: 2.0827e-04 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9918
# Epoch 341/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.1020 - val_accuracy: 0.9823
# Epoch 342/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0427 - val_accuracy: 0.9905
# Epoch 343/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0325 - val_accuracy: 0.9918
# Epoch 344/500
# 46/46 [==============================] - 0s 9ms/step - loss: 6.1414e-04 - accuracy: 0.9998 - val_loss: 0.0334 - val_accuracy: 0.9925
# Epoch 345/500
# ...
# Epoch 394/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.0316 - val_accuracy: 0.9905
# Epoch 395/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0240 - val_accuracy: 0.9939
# Epoch 396/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0233 - val_accuracy: 0.9932
# Epoch 397/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0220 - val_accuracy: 0.9939
# Epoch 398/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.8999e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9952
# Epoch 399/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.3609e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9952
# Epoch 400/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.1813e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9952
# Epoch 401/500
# 46/46 [==============================] - 1s 11ms/step - loss: 3.1509e-04 - accuracy: 0.9998 - val_loss: 0.0181 - val_accuracy: 0.9959
# Epoch 402/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0140 - val_accuracy: 0.9946
# Epoch 403/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0405 - val_accuracy: 0.9898
# Epoch 404/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0397 - val_accuracy: 0.9871
# Epoch 405/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0158 - val_accuracy: 0.9939
# Epoch 406/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0690 - val_accuracy: 0.9884
# Epoch 407/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 0.0146 - val_accuracy: 0.9959
# Epoch 408/500
# 46/46 [==============================] - 0s 10ms/step - loss: 9.6617e-04 - accuracy: 0.9998 - val_loss: 0.0133 - val_accuracy: 0.9959
# Epoch 409/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.8425e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9959
# Epoch 410/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.4509e-04 - accuracy: 0.9997 - val_loss: 0.0092 - val_accuracy: 0.9959
# Epoch 411/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0254 - val_accuracy: 0.9946
# Epoch 412/500
# 46/46 [==============================] - 0s 11ms/step - loss: 5.7033e-04 - accuracy: 0.9998 - val_loss: 0.0239 - val_accuracy: 0.9952
# Epoch 413/500
# 46/46 [==============================] - 1s 11ms/step - loss: 1.2216e-04 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9959
# Epoch 414/500
# 46/46 [==============================] - 0s 11ms/step - loss: 1.1037e-04 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9959
# Epoch 415/500
# 46/46 [==============================] - 0s 10ms/step - loss: 6.4800e-05 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9952
# Epoch 416/500
# 46/46 [==============================] - 0s 10ms/step - loss: 4.0636e-05 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9966
# Epoch 417/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.5409e-05 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9959
# Epoch 418/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.3771e-05 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9959
# Epoch 419/500
# 46/46 [==============================] - 0s 10ms/step - loss: 4.0867e-05 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9966
# Epoch 420/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.7534e-05 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9966
# Epoch 421/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.3381e-05 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9959
# Epoch 422/500
# 46/46 [==============================] - 0s 11ms/step - loss: 2.9447e-05 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9966
# Epoch 423/500
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0080 - accuracy: 0.9983 - val_loss: 0.0211 - val_accuracy: 0.9918
# Epoch 424/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 0.0259 - val_accuracy: 0.9891
# Epoch 425/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.0193 - val_accuracy: 0.9932
# Epoch 426/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0306 - val_accuracy: 0.9912
# Epoch 427/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0161 - val_accuracy: 0.9952
# Epoch 428/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.9174e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9946
# Epoch 429/500
# 46/46 [==============================] - 0s 11ms/step - loss: 2.0555e-04 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9939
# Epoch 430/500
# 46/46 [==============================] - 1s 11ms/step - loss: 1.2322e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9932
# Epoch 431/500
# 46/46 [==============================] - 0s 11ms/step - loss: 7.7226e-05 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9932
# Epoch 432/500
# 46/46 [==============================] - 1s 11ms/step - loss: 8.9168e-05 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9932
# Epoch 433/500
# 46/46 [==============================] - 0s 10ms/step - loss: 6.4853e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9939
# Epoch 434/500
# 46/46 [==============================] - 0s 11ms/step - loss: 9.6603e-05 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9939
# Epoch 435/500
# 46/46 [==============================] - 0s 10ms/step - loss: 6.3153e-05 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9946
# Epoch 436/500
# 46/46 [==============================] - 0s 10ms/step - loss: 7.7990e-04 - accuracy: 0.9998 - val_loss: 0.0327 - val_accuracy: 0.9932
# Epoch 437/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 0.9988 - val_loss: 0.0225 - val_accuracy: 0.9918
# Epoch 438/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0309 - val_accuracy: 0.9912
# Epoch 439/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0206 - val_accuracy: 0.9932
# Epoch 440/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0345 - val_accuracy: 0.9898
# Epoch 441/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0220 - val_accuracy: 0.9918
# Epoch 442/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.0161 - val_accuracy: 0.9952
# Epoch 443/500
# 46/46 [==============================] - 0s 11ms/step - loss: 6.9496e-04 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9952
# Epoch 444/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.0665e-04 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9946
# Epoch 445/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.0097e-04 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9946
# Epoch 446/500
# 46/46 [==============================] - 0s 11ms/step - loss: 8.3585e-04 - accuracy: 0.9997 - val_loss: 0.0320 - val_accuracy: 0.9905
# Epoch 447/500
# 46/46 [==============================] - 0s 11ms/step - loss: 8.7920e-04 - accuracy: 0.9997 - val_loss: 0.0154 - val_accuracy: 0.9959
# Epoch 448/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.0969e-04 - accuracy: 0.9998 - val_loss: 0.0147 - val_accuracy: 0.9959
# Epoch 449/500
# 46/46 [==============================] - 0s 10ms/step - loss: 4.3981e-04 - accuracy: 0.9998 - val_loss: 0.0220 - val_accuracy: 0.9939
# Epoch 450/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.3122e-04 - accuracy: 0.9998 - val_loss: 0.0210 - val_accuracy: 0.9952
# Epoch 451/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0175 - val_accuracy: 0.9952
# Epoch 452/500
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0200 - val_accuracy: 0.9939
# Epoch 453/500
# 46/46 [==============================] - 0s 11ms/step - loss: 8.0662e-04 - accuracy: 0.9995 - val_loss: 0.0155 - val_accuracy: 0.9952
# Epoch 454/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0147 - val_accuracy: 0.9946
# Epoch 455/500
# 46/46 [==============================] - 0s 10ms/step - loss: 7.1475e-04 - accuracy: 0.9998 - val_loss: 0.0149 - val_accuracy: 0.9952
# Epoch 456/500
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0173 - val_accuracy: 0.9952
# Epoch 457/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.0237 - val_accuracy: 0.9898
# Epoch 458/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0250 - val_accuracy: 0.9918
# Epoch 459/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0250 - val_accuracy: 0.9925
# Epoch 460/500
# 46/46 [==============================] - 0s 11ms/step - loss: 8.0185e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9946
# Epoch 461/500
# 46/46 [==============================] - 0s 11ms/step - loss: 7.3590e-04 - accuracy: 0.9998 - val_loss: 0.0145 - val_accuracy: 0.9939
# Epoch 462/500
# 46/46 [==============================] - 0s 10ms/step - loss: 8.3549e-04 - accuracy: 0.9995 - val_loss: 0.0192 - val_accuracy: 0.9939
# Epoch 463/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0129 - val_accuracy: 0.9966
# Epoch 464/500
# 46/46 [==============================] - 1s 12ms/step - loss: 1.8772e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9966
# Epoch 465/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0209 - val_accuracy: 0.9939
# Epoch 466/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0179 - val_accuracy: 0.9932
# Epoch 467/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.0416e-04 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9959
# Epoch 468/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.6931e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9966
# Epoch 469/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0176 - val_accuracy: 0.9946
# Epoch 470/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0158 - val_accuracy: 0.9959
# Epoch 471/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.4107e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9966
# Epoch 472/500
# 46/46 [==============================] - 0s 11ms/step - loss: 2.2386e-04 - accuracy: 0.9998 - val_loss: 0.0113 - val_accuracy: 0.9959
# Epoch 473/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0233 - val_accuracy: 0.9939
# Epoch 474/500
# 46/46 [==============================] - 0s 11ms/step - loss: 2.8183e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9939
# Epoch 475/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.2475e-04 - accuracy: 0.9998 - val_loss: 0.0315 - val_accuracy: 0.9932
# Epoch 476/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.4195e-05 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9932
# Epoch 477/500
# 46/46 [==============================] - 0s 10ms/step - loss: 5.3031e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9946
# Epoch 478/500
# 46/46 [==============================] - 0s 10ms/step - loss: 3.0585e-05 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9946
# Epoch 479/500
# 46/46 [==============================] - 0s 10ms/step - loss: 4.4800e-05 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9959
# Epoch 480/500
# 46/46 [==============================] - 1s 11ms/step - loss: 1.7635e-04 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9966
# Epoch 481/500
# 46/46 [==============================] - 0s 11ms/step - loss: 1.2347e-04 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9952
# Epoch 482/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 0.0194 - val_accuracy: 0.9918
# Epoch 483/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0325 - accuracy: 0.9898 - val_loss: 0.0407 - val_accuracy: 0.9810
# Epoch 484/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 485/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0181 - val_accuracy: 0.9939
# Epoch 486/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0129 - val_accuracy: 0.9966
# Epoch 487/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 0.0228 - val_accuracy: 0.9918
# Epoch 488/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9946
# Epoch 489/500
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0181 - val_accuracy: 0.9952
# Epoch 490/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0176 - val_accuracy: 0.9959
# Epoch 491/500
# 46/46 [==============================] - 1s 12ms/step - loss: 2.7409e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9959
# Epoch 492/500
# 46/46 [==============================] - 0s 11ms/step - loss: 2.1204e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9959
# Epoch 493/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.3203e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9959
# Epoch 494/500
# 46/46 [==============================] - 0s 10ms/step - loss: 7.2907e-05 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9966
# Epoch 495/500
# 46/46 [==============================] - 0s 10ms/step - loss: 6.4897e-05 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9973
# Epoch 496/500
# 46/46 [==============================] - 0s 11ms/step - loss: 1.3847e-04 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9966
# Epoch 497/500
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0171 - val_accuracy: 0.9946
# Epoch 498/500
# 46/46 [==============================] - 0s 10ms/step - loss: 1.4508e-04 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9966
# Epoch 499/500
# 46/46 [==============================] - 0s 10ms/step - loss: 2.3034e-04 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9959
# Epoch 500/500
# 46/46 [==============================] - 0s 10ms/step - loss: 9.4188e-05 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9959
# 46/46 [==============================] - 1s 4ms/step
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9959
# Fold score (Accuracy): [0.01579003967344761, 0.9959183931350708]
# Final, out of sample score (Accuracy): 0.9930631120783461
